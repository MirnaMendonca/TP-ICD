# %%
import pandas as pd

# %%
#from google.colab import drive
#drive.mount('/content/drive/')
#%cd /content/drive/My Drive/Colab Notebooks/ICD

TT_2020 = pd.read_csv('../data/TikTok_songs_2020.csv')
TT_2021 = pd.read_csv('../data/TikTok_songs_2021.csv')
TT_2022 = pd.read_csv('../data/TikTok_songs_2022.csv')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# /content/drive/My Drive/Colab Notebooks/ICD

# %%
# TT_2020 = pd.read_csv('TikTok_songs_2020.csv')
# TT_2021 = pd.read_csv('TikTok_songs_2021.csv')
# TT_2022 = pd.read_csv('TikTok_songs_2022.csv')

TT_2020['year'] = 2020
TT_2021['year'] = 2021
TT_2022['year'] = 2022

# %%
TT_2020.head()
# Out:
#                          track_name          artist_name  artist_pop  \
# 0                            Say So             Doja Cat          88
# 1                   Blinding Lights           The Weeknd          93
# 2  Supalonely (feat. Gus Dapperton)                BENEE          67
# 3                            Savage  Megan Thee Stallion          82
# 4                Moral of the Story                 Ashe          68
#
#                 album  track_pop  danceability  energy  loudness  mode  key  \
# 0            Hot Pink         80         0.787   0.673    -4.583     0   11
# 1         After Hours         90         0.514   0.730    -5.934     1    1
# 2             Hey u x         63         0.862   0.631    -4.746     1    7
# 3                Suga         70         0.843   0.741    -5.609     1   11
# 4  Moral of the Story         76         0.572   0.406    -8.624     1   10
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
TT_2021.head()
# Out:
#                                track_name    artist_name  artist_pop  \
# 0               STAY (with Justin Bieber)  The Kid LAROI          83
# 1  Peaches (feat. Daniel Caesar & Giveon)  Justin Bieber          90
# 2              edamame (feat. Rich Brian)          bbno$          72
# 3                     Here's Your Perfect   Jamie Miller          65
# 4                                It's You        Sezairi          57
#
#                         album  track_pop  danceability  energy  loudness  \
# 0   STAY (with Justin Bieber)         89         0.591   0.764    -5.484
# 1                     Justice         86         0.677   0.696    -6.181
# 2  edamame (feat. Rich Brian)         77         0.815   0.848    -4.704
# 3         Here's Your Perfect         77         0.558   0.454    -5.335
# 4                    It's You         73         0.630   0.456    -8.285
#
#    mode  key  speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %%
TT_2022.head()
# Out:
#                                track_name    artist_name  artist_pop  \
# 0  Running Up That Hill (A Deal With God)      Kate Bush          81
# 1                               As It Was   Harry Styles          91
# 2                                 Sunroof    Nicky Youre          73
# 3                              Heat Waves  Glass Animals          80
# 4                         About Damn Time          Lizzo          81
#
#                         album  track_pop  danceability  energy  loudness  \
# 0              Hounds Of Love         95         0.629   0.547   -13.123
# 1                   As It Was         96         0.520   0.731    -5.338
# 2                     Sunroof         44         0.768   0.716    -5.110
# 3  Dreamland (+ Bonus Levels)         89         0.761   0.525    -6.900
# 4             About Damn Time         92         0.836   0.743    -6.305
#
#    mode  key  speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %%
TT = pd.concat([TT_2020, TT_2021, TT_2022])
TT.head()
# Out:
#                          track_name          artist_name  artist_pop  \
# 0                            Say So             Doja Cat          88
# 1                   Blinding Lights           The Weeknd          93
# 2  Supalonely (feat. Gus Dapperton)                BENEE          67
# 3                            Savage  Megan Thee Stallion          82
# 4                Moral of the Story                 Ashe          68
#
#                 album  track_pop  danceability  energy  loudness  mode  key  \
# 0            Hot Pink         80         0.787   0.673    -4.583     0   11
# 1         After Hours         90         0.514   0.730    -5.934     1    1
# 2             Hey u x         63         0.862   0.631    -4.746     1    7
# 3                Suga         70         0.843   0.741    -5.609     1   11
# 4  Moral of the Story         76         0.572   0.406    -8.624     1   10
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# ...

# %%
TT.tail()
# Out:
#                         track_name      artist_name  artist_pop  \
# 258     The Less I Know The Better      Tame Impala          78
# 259                     Dandelions          Ruth B.          75
# 260  Jimmy Cooks (feat. 21 Savage)            Drake          95
# 261                   Good Looking  Suki Waterhouse          64
# 262                        INFERNO        Sub Urban          67
#
#                    album  track_pop  danceability  energy  loudness  mode  \
# 258             Currents         84         0.640   0.740    -4.083     1
# 259           Safe Haven         90         0.609   0.692    -2.958     1
# 260  Honestly, Nevermind         92         0.529   0.673    -4.711     1
# 261         Good Looking         80         0.377   0.558    -9.076     1
# 262              INFERNO         71         0.820   0.611    -5.020     0
#
#      key  speechiness  acousticness  instrumentalness  liveness  valence  \
# ...

# %%
TT_2020.describe()
# Out:
#        artist_pop  track_pop  danceability      energy    loudness  \
# count  292.000000  292.00000    292.000000  292.000000  292.000000
# mean    67.318493   61.19863      0.725404    0.612855   -6.884469
# std     16.571140   20.78498      0.143129    0.163366    2.697198
# min      0.000000    0.00000      0.174000    0.045800  -23.928000
# 25%     57.750000   57.00000      0.651000    0.489250   -8.369750
# 50%     69.000000   66.00000      0.734500    0.631000   -6.523000
# 75%     80.000000   74.00000      0.831750    0.729000   -4.983500
# max     95.000000   90.00000      0.980000    0.955000   -2.607000
#
#              mode         key  speechiness  acousticness  instrumentalness  \
# count  292.000000  292.000000   292.000000    292.000000        292.000000
# mean     0.534247    5.041096     0.150245      0.232500          0.028654
# std      0.499682    3.689638     0.150504      0.255970          0.114149
# ...

# %%
TT_2021.describe()
# Out:
#        artist_pop   track_pop  danceability      energy    loudness  \
# count  190.000000  190.000000    190.000000  190.000000  190.000000
# mean    70.878947   65.578947      0.708105    0.672700   -5.929774
# std     15.301246   22.917417      0.116882    0.149721    2.305945
# min      0.000000    0.000000      0.386000    0.184000  -17.667000
# 25%     63.000000   63.000000      0.651000    0.578250   -7.040750
# 50%     73.500000   73.000000      0.710000    0.692000   -5.703000
# 75%     82.000000   79.000000      0.784250    0.790000   -4.322750
# max     95.000000   91.000000      0.949000    0.989000   -1.609000
#
#              mode         key  speechiness  acousticness  instrumentalness  \
# count  190.000000  190.000000   190.000000    190.000000        190.000000
# mean     0.621053    4.894737     0.093522      0.204124          0.007814
# std      0.486407    3.661537     0.092847      0.222932          0.052535
# ...

# %%
TT_2022.describe()
# Out:
#        artist_pop   track_pop  danceability      energy    loudness  \
# count  263.000000  263.000000    263.000000  263.000000  263.000000
# mean    64.186312   59.844106      0.715338    0.682631   -6.300513
# std     18.146338   24.976524      0.117722    0.141756    1.905114
# min     18.000000    0.000000      0.308000    0.214000  -13.468000
# 25%     50.000000   47.000000      0.646000    0.593000   -7.423500
# 50%     64.000000   66.000000      0.726000    0.701000   -6.067000
# 75%     81.000000   79.500000      0.796500    0.790500   -4.887000
# max     95.000000   97.000000      0.961000    0.955000   -2.634000
#
#              mode         key  speechiness  acousticness  instrumentalness  \
# count  263.000000  263.000000   263.000000    263.000000        263.000000
# mean     0.536122    5.809886     0.117268      0.193188          0.020244
# std      0.499644    3.657312     0.101417      0.214588          0.109370
# ...

# %%
TT.describe()
# Out:
#        artist_pop   track_pop  danceability      energy    loudness  \
# count  745.000000  745.000000    745.000000  745.000000  745.000000
# mean    67.120805   61.837584      0.717439    0.652750   -6.434842
# std     17.014902   22.961145      0.128110    0.155729    2.371747
# min      0.000000    0.000000      0.174000    0.045800  -23.928000
# 25%     57.000000   53.000000      0.650000    0.542000   -7.636000
# 50%     69.000000   69.000000      0.725000    0.673000   -6.135000
# 75%     81.000000   78.000000      0.802000    0.773000   -4.753000
# max     95.000000   97.000000      0.980000    0.989000   -1.609000
#
#              mode         key  speechiness  acousticness  instrumentalness  \
# count  745.000000  745.000000   745.000000    745.000000        745.000000
# mean     0.557047    5.275168     0.124137      0.211385          0.020371
# std      0.497069    3.687853     0.123269      0.234037          0.100384
# ...

# %%
TT.dropna(inplace=True)
TT.reset_index(drop=True, inplace=True)
TT.tail()
# Out:
#                         track_name      artist_name  artist_pop  \
# 740     The Less I Know The Better      Tame Impala          78
# 741                     Dandelions          Ruth B.          75
# 742  Jimmy Cooks (feat. 21 Savage)            Drake          95
# 743                   Good Looking  Suki Waterhouse          64
# 744                        INFERNO        Sub Urban          67
#
#                    album  track_pop  danceability  energy  loudness  mode  \
# 740             Currents         84         0.640   0.740    -4.083     1
# 741           Safe Haven         90         0.609   0.692    -2.958     1
# 742  Honestly, Nevermind         92         0.529   0.673    -4.711     1
# 743         Good Looking         80         0.377   0.558    -9.076     1
# 744              INFERNO         71         0.820   0.611    -5.020     0
#
#      key  speechiness  acousticness  instrumentalness  liveness  valence  \
# ...
